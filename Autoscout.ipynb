# %%
pip install polars
# Out:
# Collecting polars
#   Downloading polars-1.38.1-py3-none-any.whl.metadata (10 kB)
# Collecting polars-runtime-32==1.38.1 (from polars)
#   Downloading polars_runtime_32-1.38.1-cp310-abi3-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Downloading polars-1.38.1-py3-none-any.whl (810 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 810.4/810.4 kB 10.3 MB/s  0:00:00
# Downloading polars_runtime_32-1.38.1-cp310-abi3-macosx_11_0_arm64.whl (40.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 MB 37.3 MB/s  0:00:01 eta 0:00:010:0101
# Installing collected packages: polars-runtime-32, polars
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [polars]━━━━ 1/2 [polars]
# Successfully installed polars-1.38.1 polars-runtime-32-1.38.1
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (25.2)
# Collecting pip
#   Downloading pip-26.0.1-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-26.0.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 17.9 MB/s  0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 25.2
#     Uninstalling pip-25.2:
#       Successfully uninstalled pip-25.2
# Successfully installed pip-26.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import polars as pl

# %%
pip install pandas
# Out:
# 256.78s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Collecting pandas
#   Downloading pandas-3.0.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (79 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.4.2-cp313-cp313-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.1-cp313-cp313-macosx_11_0_arm64.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 37.3 MB/s  0:00:006.3 MB/s eta 0:00:01
# Downloading numpy-2.4.2-cp313-cp313-macosx_14_0_arm64.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 50.9 MB/s  0:00:00
# Installing collected packages: numpy, pandas
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 1/2 [pandas]

# %%
import pandas as pd

df_sample = pd.read_csv("Desktop/autoscout24_dataset_20251108.csv", nrows=1000)
print(df_sample.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 75 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   id                                    1000 non-null   str
#  1   description                           956 non-null    str
#  2   ratings_average                       635 non-null    str
#  3   ratings_count                         635 non-null    float64
#  4   ratings_recommend_percentage          635 non-null    float64
#  5   price_currency                        1000 non-null   str
#  6   price                                 1000 non-null   float64
#  7   price_tax_deductible                  1000 non-null   bool
#  8   price_negotiable                      1000 non-null   bool
#  9   price_net                             279 non-null    float64
#  10  price_vat_rate                        262 non-null    float64
#  11  vin                                   337 non-null    str
#  12  make                                  1000 non-null   str
#  13  model                                 992 non-null    str
#  14  model_version                         995 non-null    str
#  15  german_hsn_tsn                        261 non-null    str
#  16  mileage_km_raw                        993 non-null    float64
#  17  mileage_km                            993 non-null    str
#  18  registration_date                     998 non-null    str
#  19  production_year                       184 non-null    float64
#  20  vehicle_type                          1000 non-null   str
#  21  body_type                             1000 non-null   str
#  22  nr_seats                              957 non-null    float64
#  23  nr_doors                              986 non-null    float64
#  24  body_color                            889 non-null    str
#  25  paint_type                            782 non-null    str
#  26  body_color_original                   633 non-null    str
#  27  upholstery                            763 non-null    str
#  28  upholstery_color                      726 non-null    str
#  29  power_kw                              989 non-null    float64
#  30  power_hp                              989 non-null    float64
#  31  transmission                          990 non-null    str
#  32  gears                                 626 non-null    float64
#  33  drive_train                           757 non-null    str
#  34  cylinders                             796 non-null    float64
#  35  cylinders_volume_cc                   897 non-null    float64
#  36  weight_kg                             820 non-null    str
#  37  has_particle_filter                   1000 non-null   bool
#  38  fuel_category                         1000 non-null   str
#  39  primary_fuel                          513 non-null    str
#  40  electric_range_km                     109 non-null    float64
#  41  electric_range_city_km                6 non-null      float64
#  42  fuel_cons_comb_l100_km                355 non-null    float64
#  43  fuel_cons_city_l100_km                0 non-null      float64
#  44  fuel_cons_highway_l100_km             0 non-null      float64
#  45  co2_emission_grper_km                 203 non-null    float64
#  46  fuel_cons_comb_l100_wltp_km           267 non-null    float64
#  47  fuel_cons_electric_comb_l100_wltp_km  39 non-null     float64
#  48  co2_emission_grper_wltp_km            409 non-null    float64
#  49  equipment_comfort                     1000 non-null   str
#  50  equipment_entertainment               1000 non-null   str
#  51  equipment_extra                       1000 non-null   str
#  52  equipment_safety                      1000 non-null   str
#  53  is_used                               1000 non-null   bool
#  54  is_new                                1000 non-null   bool
#  55  is_preregistered                      1000 non-null   bool
#  56  had_accident                          1000 non-null   bool
#  57  has_full_service_history              1000 non-null   bool
#  58  non_smoking                           1000 non-null   bool
#  59  nr_prev_owners                        539 non-null    float64
#  60  is_rental                             1000 non-null   bool
#  61  envir_standard                        640 non-null    str
#  62  original_market                       377 non-null    str
#  63  offer_type                            1000 non-null   str
#  64  country_code                          1000 non-null   str
#  65  zip                                   1000 non-null   str
#  66  city                                  999 non-null    str
#  67  street                                826 non-null    str
#  68  latitude                              997 non-null    float64
#  69  longitude                             997 non-null    float64
#  70  seller_is_dealer                      1000 non-null   bool
#  71  seller_type                           1000 non-null   str
#  72  seller_company_name                   830 non-null    str
#  73  has_warranty                          0 non-null      float64
#  74  warranty                              0 non-null      float64
# dtypes: bool(11), float64(28), str(36)
# memory usage: 510.9 KB
# None

# %%
cols = [
    "id",
    "make",
    "model",
    "registration_date",
    "production_year",
    "price",
    "mileage_km_raw",
    "fuel_category",
    "cylinders_volume_cc",
    "body_type",
    "fuel_cons_comb_l100_km",
    "fuel_cons_comb_l100_wltp_km",
    "fuel_cons_electric_comb_l100_wltp_km"
]

df = pd.read_csv("Desktop/autoscout24_dataset_20251108.csv", usecols=cols)

# %%
df["year"] = df["production_year"]

df["registration_year"] = pd.to_datetime(
    df["registration_date"],
    errors="coerce"
).dt.year

df["year"] = df["year"].fillna(df["registration_year"])

df.drop(columns=[
    "production_year",
    "registration_date",
    "registration_year"
], inplace=True)

# %%
# Numeric downcasting
num_cols = [
    "year",
    "price",
    "mileage_km_raw",
    "cylinders_volume_cc",
    "fuel_cons_comb_l100_km",
    "fuel_cons_comb_l100_wltp_km",
    "fuel_cons_electric_comb_l100_wltp_km"
]

for col in num_cols:
    df[col] = pd.to_numeric(df[col], downcast="float")

# Convert to category
cat_cols = ["make", "model", "fuel_category", "body_type"]

for col in cat_cols:
    df[col] = df[col].astype("category")

# %%
df.shape
# Out:
# (118382, 12)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 118382 entries, 0 to 118381
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   id                                    118382 non-null  str
#  1   price                                 118382 non-null  float64
#  2   make                                  118382 non-null  str
#  3   model                                 116980 non-null  str
#  4   mileage_km_raw                        117738 non-null  float64
#  5   body_type                             118382 non-null  str
#  6   cylinders_volume_cc                   106096 non-null  float64
#  7   fuel_category                         118309 non-null  str
#  8   fuel_cons_comb_l100_km                41844 non-null   float64
#  9   fuel_cons_comb_l100_wltp_km           30270 non-null   float64
#  10  fuel_cons_electric_comb_l100_wltp_km  4926 non-null    float64
#  11  year                                  118226 non-null  float64
# dtypes: float64(7), str(5)
# memory usage: 10.8 MB

# %%
df.isna().mean().sort_values(ascending=False)
# Out:
# fuel_cons_electric_comb_l100_wltp_km    0.958389
# fuel_cons_comb_l100_wltp_km             0.744302
# fuel_cons_comb_l100_km                  0.646534
# cylinders_volume_cc                     0.103783
# model                                   0.011843
# mileage_km_raw                          0.005440
# year                                    0.001318
# fuel_category                           0.000617
# id                                      0.000000
# price                                   0.000000
# make                                    0.000000
# body_type                               0.000000
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,5))
sns.histplot(df["price"], bins=50)
plt.title("Price Distribution")
plt.show()

# %%
df["price"].describe()
# Out:
# count    1.183820e+05
# mean     5.751598e+04
# std      1.099858e+05
# min      1.000000e+00
# 25%      2.399000e+04
# 50%      3.998000e+04
# 75%      6.995000e+04
# max      1.350000e+07
# Name: price, dtype: float64

# %%
df["price"].sort_values(ascending=False).head(10)
# Out:
# 50280     13500000.0
# 16344      9500000.0
# 109272     8627500.0
# 75347      7080500.0
# 31379      6800000.0
# 118259     6799000.0
# 4497       5700000.0
# 99770      5600000.0
# 15652      5500000.0
# 43225      5429000.0
# Name: price, dtype: float64

# %%
upper_limit = df["price"].quantile(0.99)
df_clean = df[df["price"] < upper_limit]

# %%
plt.figure(figsize=(8,5))
sns.histplot(df_clean["price"], bins=50)
plt.title("Price Distribution (Without Top 1%) Euros")
plt.show()

# %%
#Price Distribution Insights

#The price distribution is strongly right-skewed.

#Most vehicles are concentrated between 20k–60k.

#A long tail extends beyond 150k.

# Top 1% of extreme outliers were removed for visualization clarity.

# %%
import numpy as np

df_clean["log_price"] = np.log1p(df_clean["price"])

plt.figure(figsize=(8,5))
sns.regplot(
    x="year",
    y="log_price",
    data=df_clean,
    scatter_kws={"alpha":0.2}
)
plt.title("Log Price vs Production Year")
plt.show()

# %%
df_clean["year"].describe()
# Out:
# count    117080.000000
# mean       2019.797506
# std           5.633233
# min        1929.000000
# 25%        2018.000000
# 50%        2021.000000
# 75%        2025.000000
# max        2026.000000
# Name: year, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["year"], bins=60)
plt.title("Year Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["fuel_cons_comb_l100_km"], bins=20)
plt.title("Fuel Consumption")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(df["fuel_category"], bins=60)
plt.title("Fuel Category")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=df, x="make", order=df["make"].value_counts().index)
plt.xticks(rotation=90)
plt.title("Car Brand Frequency")
plt.tight_layout()
plt.show()

# %%
counts_fuel = df["fuel_category"].value_counts()

plt.figure(figsize=(8,5))
sns.barplot(y=counts_fuel.index, x=counts_fuel.values)
plt.title("Fuel Category")
plt.tight_layout()
plt.show()

# %%
df.to_csv("autoscoutdf.csv", index=False)

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=df, x="make", y="price")
plt.xticks(rotation=90)
plt.title("Price distribution by car brand")
plt.tight_layout()
plt.show()

# %%
df.groupby("make")["price"].mean().sort_values(ascending=False)
# Out:
# make
# Bugatti          4.550384e+06
# Rolls-Royce      2.806976e+05
# Maybach          2.507136e+05
# Aston Martin     2.489276e+05
# Porsche          9.777541e+04
# Mercedes-Benz    7.065229e+04
# Maserati         6.245030e+04
# Audi             5.888835e+04
# BYD              3.750224e+04
# BMW              3.447126e+04
# Tesla            3.064492e+04
# Alfa Romeo       2.672806e+04
# Kia              2.072920e+04
# Dongfeng         1.952602e+04
# SsangYong        1.941620e+04
# Hyundai          1.725858e+04
# Volvo            1.707836e+04
# Suzuki           1.674616e+04
# smart            1.580308e+04
# Mitsubishi       1.550770e+04
# Renault          1.320090e+04
# Volkswagen       1.199204e+04
# Honda            1.180711e+04
# Ford             1.164386e+04
# Opel             1.107020e+04
# Name: price, dtype: float64

# %%
avg_price = df.groupby("make", as_index=False)["price"].mean()
avg_price.sort_values("price", ascending=False)
# Out:
#              make         price
# 5         Bugatti  4.550384e+06
# 18    Rolls-Royce  2.806976e+05
# 12        Maybach  2.507136e+05
# 1    Aston Martin  2.489276e+05
# 16        Porsche  9.777541e+04
# 13  Mercedes-Benz  7.065229e+04
# 11       Maserati  6.245030e+04
# 2            Audi  5.888835e+04
# 4             BYD  3.750224e+04
# 3             BMW  3.447126e+04
# 21          Tesla  3.064492e+04
# 0      Alfa Romeo  2.672806e+04
# 10            Kia  2.072920e+04
# 6        Dongfeng  1.952602e+04
# 19      SsangYong  1.941620e+04
# 9         Hyundai  1.725858e+04
# 23          Volvo  1.707836e+04
# 20         Suzuki  1.674616e+04
# 24          smart  1.580308e+04
# 14     Mitsubishi  1.550770e+04
# 17        Renault  1.320090e+04
# 22     Volkswagen  1.199204e+04
# 8           Honda  1.180711e+04
# 7            Ford  1.164386e+04
# 15           Opel  1.107020e+04

# %%
import scipy.stats as stats

groups = [g["price"].dropna() for _, g in df.groupby("make")]
stats.f_oneway(*groups)
# Out:
# F_onewayResult(statistic=np.float64(4534.412090338282), pvalue=np.float64(0.0))

# %%
top_brands = df["make"].value_counts().nlargest(12).index

plt.figure(figsize=(12,6))
sns.boxplot(data=df[df["make"].isin(top_brands)], x="make", y="price")
plt.xticks(rotation=90)
plt.title("Price distribution for top 12 car brands")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=df, x="make", y="price")
plt.yscale("log")
plt.xticks(rotation=90)
plt.title("Price log figure boxplot")
plt.show()

# %%
df.groupby("make")["year"].min()
# Out:
# make
# Alfa Romeo       2000.0
# Aston Martin     1958.0
# Audi             1992.0
# BMW              1999.0
# BYD              2022.0
# Bugatti          1935.0
# Dongfeng         2019.0
# Ford             2002.0
# Honda            2009.0
# Hyundai          2013.0
# Kia              2014.0
# Maserati         1970.0
# Maybach          2003.0
# Mercedes-Benz    2015.0
# Mitsubishi       1987.0
# Opel             2003.0
# Porsche          1963.0
# Renault          1995.0
# Rolls-Royce      1929.0
# SsangYong        1997.0
# Suzuki           2000.0
# Tesla            2015.0
# Volkswagen       1998.0
# Volvo            2000.0
# smart            2000.0
# Name: year, dtype: float64

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=df, x="make", y="year")
plt.xticks(rotation=90)
plt.title("Price boxplot by make and year")
plt.show()
